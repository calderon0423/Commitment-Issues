# %%
#Data cleanup here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import csv
import json
import requests
import seaborn as sns
import time

# %%
# Pull csv using URL of dataset uploaded to repo

url = 'https://raw.githubusercontent.com/calderon0423/Commitment-Issues/master/Dataset/'

all_homes = pd.read_csv(f'{url}State_MedianRentalPrice_AllHomes.csv')
del all_homes['Unnamed: 0']
all_homes.head()
# Out:
#    RegionName  SizeRank  2010-01  2010-02  2010-03  2010-04  2010-05  2010-06  \
# 0  California         1      NaN      NaN   2400.0   2400.0   2400.0   2495.0
# 1       Texas         2      NaN      NaN      NaN      NaN      NaN      NaN
# 2    New York         3      NaN      NaN      NaN      NaN      NaN      NaN
# 3     Florida         4      NaN      NaN      NaN      NaN      NaN      NaN
# 4    Illinois         5   1575.0   1500.0   1500.0   1500.0   1500.0   1500.0
#
#    2010-07  2010-08  ...  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 0   2500.0   2595.0  ...   2750.0     2800   2800.0   2800.0   2800.0
# 1      NaN      NaN  ...   1550.0     1575   1595.0   1595.0   1600.0
# 2      NaN      NaN  ...   3200.0     3495   3299.0   3295.0   3200.0
# 3      NaN      NaN  ...   1850.0     1850   1850.0   1845.0   1800.0
# 4   1550.0   1520.0  ...   1600.0     1600   1600.0   1642.5   1647.0
#
#    2019-08  2019-09  2019-10  2019-11  2019-12
# ...

# %%
all_homes_2015 = all_homes[['RegionName', 'SizeRank', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
                           '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
                           ]]
all_homes_2015 = all_homes_2015.dropna()
avg_2015 = all_homes_2015[['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
                           '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
                           ]]
avg_2015['2015 Avg'] = round(avg_2015.mean(axis=1), 2)
avg_2015["RegionName"] = all_homes_2015["RegionName"]
avg_2015 = avg_2015[["RegionName", "2015 Avg"]]
avg_2015.head()
# Out:
# C:\Users\julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    RegionName  2015 Avg
# 0  California   2236.17
# 1       Texas   1407.92
# 2    New York   3106.50
# 3     Florida   1643.33
# 4    Illinois   1587.00

# %%
all_homes_2016 = all_homes[['RegionName', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
                           '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
                           ]]
all_homes_2016 = all_homes_2016.dropna()
avg_2016 = all_homes_2016[['2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
                           '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12'
                           ]]
avg_2016['2016 Avg'] = round(avg_2016.mean(axis=1), 2)
avg_2016["RegionName"] = all_homes_2016["RegionName"]
avg_2016 = avg_2016[["RegionName", "2016 Avg"]]
avg_2016.head()
# Out:
#    RegionName  2016 Avg
# 0  California   2373.75
# 1       Texas   1413.71
# 2    New York   3079.17
# 3     Florida   1676.67
# 4    Illinois   1578.33

# %%
all_homes_2017 = all_homes[['RegionName', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
                           '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
                           ]]
all_homes_2017 = all_homes_2017.dropna()
avg_2017 = all_homes_2017[['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
                           '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12'
                           ]]
avg_2017['2017 Avg'] = round(avg_2017.mean(axis=1), 2)
avg_2017["RegionName"] = all_homes_2017["RegionName"]
avg_2017 = avg_2017[["RegionName", "2017 Avg"]]
avg_2017.head()
# Out:
#    RegionName  2017 Avg
# 0  California   2602.92
# 1       Texas   1488.88
# 2    New York   3202.42
# 3     Florida   1733.75
# 4    Illinois   1586.08

# %%
new = pd.merge(avg_2015, avg_2016, on="RegionName")
new = pd.merge(new, avg_2017, on="RegionName")
sorted_2015_high = new.sort_values("2015 Avg", ascending=False)
sorted_2015_high.head(3)
# Out:
#               RegionName  2015 Avg  2016 Avg  2017 Avg
# 2               New York   3106.50   3079.17   3202.42
# 46  District of Columbia   2510.00   2535.42   2605.42
# 13         Massachusetts   2427.46   2464.12   2518.75

# %%
sorted_2015_low = new.sort_values("2015 Avg")
sorted_2015_low.head(3)
# Out:
#    RegionName  2015 Avg  2016 Avg  2017 Avg
# 17   Missouri    896.25    923.75    944.58
# 22    Alabama    939.58    974.17    997.50
# 7    Michigan    956.83   1018.33   1070.33

# %%
sorted_2016_high = new.sort_values("2016 Avg", ascending=False)
sorted_2016_high.head(3)
# Out:
#               RegionName  2015 Avg  2016 Avg  2017 Avg
# 2               New York   3106.50   3079.17   3202.42
# 46  District of Columbia   2510.00   2535.42   2605.42
# 13         Massachusetts   2427.46   2464.12   2518.75

# %%
sorted_2016_low = new.sort_values("2016 Avg")
sorted_2016_low.head(3)
# Out:
#    RegionName  2015 Avg  2016 Avg  2017 Avg
# 17   Missouri    896.25    923.75    944.58
# 22    Alabama    939.58    974.17    997.50
# 14    Indiana    980.83    990.17   1041.17

# %%
sorted_2017_high = new.sort_values("2017 Avg", ascending=False)
sorted_2017_high.head(3)
# Out:
#               RegionName  2015 Avg  2016 Avg  2017 Avg
# 2               New York   3106.50   3079.17   3202.42
# 46  District of Columbia   2510.00   2535.42   2605.42
# 0             California   2236.17   2373.75   2602.92

# %%
sorted_2017_low = new.sort_values("2017 Avg")
sorted_2017_low.head(3)
# Out:
#        RegionName  2015 Avg  2016 Avg  2017 Avg
# 17       Missouri    896.25    923.75    944.58
# 36  West Virginia   1080.62   1046.25    986.88
# 22        Alabama    939.58    974.17    997.50

# %%
new["'15 - '16 Change"] = new["2016 Avg"] - new["2015 Avg"]
new["'16 - '17 Change"] = new["2017 Avg"] - new["2016 Avg"]
renamed = new.rename(columns={"RegionName":"State",
                                "2015 Avg":"2015 Rent",
                                "2016 Avg":"2016 Rent",
                                 "2017 Avg":"2017 Rent",
                                 "'15 - '16 Change":"'15-'16 Rent Diff.",
                                 "'16 - '17 Change":"'16-'17 Rent Diff."})
renamed
# Out:
#                    State  2015 Rent  2016 Rent  2017 Rent  '15-'16 Rent Diff.  \
# 0             California    2236.17    2373.75    2602.92              137.58
# 1                  Texas    1407.92    1413.71    1488.88                5.79
# 2               New York    3106.50    3079.17    3202.42              -27.33
# 3                Florida    1643.33    1676.67    1733.75               33.34
# 4               Illinois    1587.00    1578.33    1586.08               -8.67
# 5           Pennsylvania    1336.00    1324.58    1337.50              -11.42
# 6                   Ohio    1003.04    1037.50    1020.75               34.46
# 7               Michigan     956.83    1018.33    1070.33               61.50
# 8                Georgia    1147.92    1198.00    1296.17               50.08
# 9         North Carolina    1098.17    1144.58    1245.42               46.41
# 10            New Jersey    1856.25    1870.83    1916.25               14.58
# ...

# %%
income_df = pd.read_csv("../household_median_income_2017.csv")
income_df = income_df.dropna(how='any')

#excluting Nebraska & United States rows to match the Zillow df. Puerto Rico was not in csv file. 
income_df = income_df.loc[income_df['State']!= 'Nebraska']
income_df = income_df.loc[income_df['State']!= 'United States'].reset_index(drop=True)
income_df = income_df[['State','2017', '2016', '2015']].sort_values('2017',ascending = False)

#removing commas & converting to int data type 
income_df["2015 Income"] = income_df["2015"].str.replace(",","").astype(int)
income_df["2016 Income"] = income_df["2016"].str.replace(",","").astype(int)
income_df["2017 Income"] = income_df["2017"].str.replace(",","").astype(int)

#replace so matches rent
income_df = income_df.drop(columns={"2017", "2016", "2015"})
income_df["State"] = income_df["State"].replace({"D.C.":"District of Columbia"})

#find difference
income_df["'15-'16 Income Diff."] = income_df['2016 Income'] - income_df['2015 Income']
income_df["'16-'17 Income Diff."] = income_df['2017 Income'] - income_df['2016 Income']

income_df = income_df.reset_index(drop=True)
income_df
# Out:
#                    State  2015 Income  2016 Income  2017 Income  \
# 0   District of Columbia        72501        72508        83382
# 1               Maryland        76146        75346        81084
# 2             Washington        69575        71822        75418
# 3          New Hampshire        78299        77900        74801
# 4               Colorado        68906        72084        74172
# 5                 Hawaii        66751        73684        73575
# 6          Massachusetts        70214        73820        73227
# 7             New Jersey        70728        69940        72997
# 8            Connecticut        75417        77556        72780
# 9                 Alaska        77717        77351        72231
# 10             Minnesota        71114        71728        71920
# 11                  Utah        68556        68932        71319
# 12              Virginia        63618        67880        71293
# 13            California        65843        68070        69759
# ...

# %%
merged = pd.merge(renamed, income_df, on="State")
merged = merged.sort_values("State")
merged
# Out:
#                    State  2015 Rent  2016 Rent  2017 Rent  '15-'16 Rent Diff.  \
# 22               Alabama     939.58     974.17     997.50               34.59
# 45                Alaska    1687.92    1643.96    1588.33              -43.96
# 15               Arizona    1224.58    1251.67    1336.46               27.09
# 31              Arkansas     998.33    1019.17    1045.00               20.84
# 0             California    2236.17    2373.75    2602.92              137.58
# 21              Colorado    1624.58    1702.50    1795.42               77.92
# 28           Connecticut    1741.67    1708.96    1747.50              -32.71
# 43              Delaware    1303.75    1312.50    1320.83                8.75
# 46  District of Columbia    2510.00    2535.42    2605.42               25.42
# 3                Florida    1643.33    1676.67    1733.75               33.34
# 8                Georgia    1147.92    1198.00    1296.17               50.08
# ...

# %%
merged.to_csv("../output_data/rental_income_merged.csv", index=False, header=True)
